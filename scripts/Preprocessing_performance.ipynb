# %%
import torch
import cv2
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import sys
import os
import pandas as pd
import json

# %%
labels_female_path = "../data/labels_female.json"
labels_male_path = "../data/labels_male.json"

# %%
# Initialize an empty list to hold the parsed JSON objects
male_target = []
try:
    # Open the file and read line by line
    with open(labels_male_path, 'r') as file:
        for line in file:
            # Parse each line as a JSON object
            json_object = json.loads(line.strip())  # Use strip() to remove any extra whitespace
            male_target.append(json_object)  # Add the parsed object to the list


except FileNotFoundError:
    print("File not found. Please check the path.")
except json.JSONDecodeError as e:
    print("Error decoding JSON:", e)

male_data = []

# Iterate through each item in the data list
for item in male_target:
    # Parse the 'scores' JSON string
    scores = json.loads(item['scores'])

    # Create a new dictionary with the required format
    processed_item = {
        'image': item['image'],
        'strength': scores['strength'],
        'romantic': scores['romantic'],
        'luck': scores['luck'],
        'potential': scores['potential']
    }

    # Append the processed item to the list
    male_data.append(processed_item)

# Create a DataFrame from the processed data
male_data = pd.DataFrame(male_data)

# %%
# Initialize an empty list to hold the parsed JSON objects
female_target = []
try:
    # Open the file and read line by line
    with open(labels_female_path, 'r') as file:
        for line in file:
            # Parse each line as a JSON object
            json_object = json.loads(line.strip())  # Use strip() to remove any extra whitespace
            female_target.append(json_object)  # Add the parsed object to the list


except FileNotFoundError:
    print("File not found. Please check the path.")
except json.JSONDecodeError as e:
    print("Error decoding JSON:", e)

female_data = []

# Iterate through each item in the data list
for item in female_target:
    # Parse the 'scores' JSON string
    scores = json.loads(item['scores'])

    # Create a new dictionary with the required format
    processed_item = {
        'image': item['image'],
        'strength': scores['strength'],
        'romantic': scores['romantic'],
        'luck': scores['luck'],
        'potential': scores['potential']
    }

    # Append the processed item to the list
    female_data.append(processed_item)

# Create a DataFrame from the processed data
female_data = pd.DataFrame(female_data)

# %%
male_data.tail()
# Out:
#                                  image  strength  romantic  luck  potential
# 395  ./Hands_kaggle2/MALE/IMG_0261.JPG       0.7       0.5   0.6        0.8
# 396  ./Hands_kaggle2/MALE/IMG_0199.JPG       0.5       0.3   0.4        0.6
# 397  ./Hands_kaggle2/MALE/IMG_0220.JPG       0.0       0.0   0.0        0.0
# 398  ./Hands_kaggle2/MALE/IMG_0174.JPG       0.6       0.4   0.5        0.7
# 399  ./Hands_kaggle2/MALE/IMG_0367.JPG       0.5       0.3   0.4        0.5

# %%
female_data.tail()
# Out:
#                                    image  strength  romantic  luck  potential
# 395  ./Hands_kaggle2/FEMALE/IMG_0261.JPG       0.7       0.6   0.5       0.80
# 396  ./Hands_kaggle2/FEMALE/IMG_0199.JPG       0.8       0.6   0.7       0.75
# 397  ./Hands_kaggle2/FEMALE/IMG_0220.JPG       0.5       0.6   0.4       0.70
# 398  ./Hands_kaggle2/FEMALE/IMG_0174.JPG       0.6       0.4   0.5       0.70
# 399  ./Hands_kaggle2/FEMALE/IMG_0367.JPG       0.6       0.6   0.5       0.70

# %%
### grab data set and label 
female_data_path = "../data2/training_dataset/FEMALE" 
edge_female_data_path = "../data2/training_dataset/EDGE_FEMALE" 
male_data_path = "../data2/training_dataset/MALE" 
edge_male_data_path = "../data2/training_dataset/EDGE_MALE" 

# Function to construct the full image path
def get_male_image_path(image_column):
    # Extract the filename from the image path in the DataFrame
    filename = os.path.basename(image_column)  # Get the filename (e.g., IMG_0182.JPG)
    # Construct the full path
    full_path = os.path.join(male_data_path, filename.replace('.JPG', '_procesed.jpg'))  # Adjust the filename if needed
    return full_path

def get_edge_male_image_path(image_column):
    # Extract the filename from the image path in the DataFrame
    filename = os.path.basename(image_column)  # Get the filename (e.g., IMG_0182.JPG)
    # Construct the full path
    full_path = os.path.join(edge_male_data_path, filename.replace('.JPG', '_processed.jpg'))  # Adjust the filename if needed
    return full_path

def get_female_image_path(image_column):
    # Extract the filename from the image path in the DataFrame
    filename = os.path.basename(image_column)  # Get the filename (e.g., IMG_0182.JPG)
    # Construct the full path
    full_path = os.path.join(female_data_path, filename.replace('.JPG', '_female.jpg'))  # Adjust the filename if needed
    return full_path

def get_edge_female_image_path(image_column):
    # Extract the filename from the image path in the DataFrame
    filename = os.path.basename(image_column)  # Get the filename (e.g., IMG_0182.JPG)
    # Construct the full path
    full_path = os.path.join(edge_female_data_path, filename.replace('.JPG', '_female.jpg'))  # Adjust the filename if needed
    return full_path

# Apply the function to create a new column with the full image paths
female_data['image_path'] = female_data['image'].apply(get_female_image_path)
female_data['edge_image_path'] = female_data['image'].apply(get_edge_female_image_path)
male_data['image_path'] = male_data['image'].apply(get_male_image_path)
male_data['edge_image_path'] = male_data['image'].apply(get_edge_male_image_path)

# %%
male_data.tail()
# Out:
#                                  image  strength  romantic  luck  potential  \
# 395  ./Hands_kaggle2/MALE/IMG_0261.JPG       0.7       0.5   0.6        0.8
# 396  ./Hands_kaggle2/MALE/IMG_0199.JPG       0.5       0.3   0.4        0.6
# 397  ./Hands_kaggle2/MALE/IMG_0220.JPG       0.0       0.0   0.0        0.0
# 398  ./Hands_kaggle2/MALE/IMG_0174.JPG       0.6       0.4   0.5        0.7
# 399  ./Hands_kaggle2/MALE/IMG_0367.JPG       0.5       0.3   0.4        0.5
#
#                                             image_path  \
# 395  ../data2/training_dataset/MALE/IMG_0261_proces...
# 396  ../data2/training_dataset/MALE/IMG_0199_proces...
# 397  ../data2/training_dataset/MALE/IMG_0220_proces...
# 398  ../data2/training_dataset/MALE/IMG_0174_proces...
# 399  ../data2/training_dataset/MALE/IMG_0367_proces...
#
#                                        edge_image_path
# 395  ../data2/training_dataset/EDGE_MALE/IMG_0261_p...
# 396  ../data2/training_dataset/EDGE_MALE/IMG_0199_p...
# 397  ../data2/training_dataset/EDGE_MALE/IMG_0220_p...
# 398  ../data2/training_dataset/EDGE_MALE/IMG_0174_p...
# 399  ../data2/training_dataset/EDGE_MALE/IMG_0367_p...

# %%
female_data.tail()
# Out:
#                                    image  strength  romantic  luck  potential  \
# 395  ./Hands_kaggle2/FEMALE/IMG_0261.JPG       0.7       0.6   0.5       0.80
# 396  ./Hands_kaggle2/FEMALE/IMG_0199.JPG       0.8       0.6   0.7       0.75
# 397  ./Hands_kaggle2/FEMALE/IMG_0220.JPG       0.5       0.6   0.4       0.70
# 398  ./Hands_kaggle2/FEMALE/IMG_0174.JPG       0.6       0.4   0.5       0.70
# 399  ./Hands_kaggle2/FEMALE/IMG_0367.JPG       0.6       0.6   0.5       0.70
#
#                                             image_path  \
# 395  ../data2/training_dataset/FEMALE/IMG_0261_fema...
# 396  ../data2/training_dataset/FEMALE/IMG_0199_fema...
# 397  ../data2/training_dataset/FEMALE/IMG_0220_fema...
# 398  ../data2/training_dataset/FEMALE/IMG_0174_fema...
# 399  ../data2/training_dataset/FEMALE/IMG_0367_fema...
#
#                                        edge_image_path
# 395  ../data2/training_dataset/EDGE_FEMALE/IMG_0261...
# 396  ../data2/training_dataset/EDGE_FEMALE/IMG_0199...
# 397  ../data2/training_dataset/EDGE_FEMALE/IMG_0220...
# 398  ../data2/training_dataset/EDGE_FEMALE/IMG_0174...
# 399  ../data2/training_dataset/EDGE_FEMALE/IMG_0367...

# %%
import sys
import os
import torchvision
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Add the subfolder to the Python path
sys.path.append(os.path.join(current_dir, '..'))

# Now you can import the module
from model.palm_ai import PalmAI
# Out:
# /Users/johnsonrj/Documents/GitHub/COMP4471-PalmAI/scripts

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = PalmAI().to(device)

# %%
from scripts.palm_transformer import *

# %%
pipeline = PalmAnalysisPipeline()
pipeline.train(
        image_dir='../data2/training_dataset/EDGE_FEMALE',
        epochs=20,  # Start with fewer epochs
        batch_size=2  # Smaller batch size
)
# Out:
# Using device: cpu
# 🚀 Starting training process...
# 📁 Found 400 images
# 📸 Sample images: ['IMG_0389_female.jpg', 'IMG_0082_female.jpg', 'IMG_0196_female.jpg']
# 📊 Train/Val split: 320/80
# 🔍 Sample shape: torch.Size([1, 224, 224])
# 🎯 Starting training loop...
# Epoch 1, Batch 0, Loss: 2.2956
# Epoch 1, Batch 5, Loss: 2.4418
# Epoch 1, Batch 10, Loss: 2.3728
# Epoch 1, Batch 15, Loss: 2.3697
# Epoch 1, Batch 20, Loss: 2.3422
# Epoch 1, Batch 25, Loss: 2.3698
# Epoch 1, Batch 30, Loss: 2.3440
# Epoch 1, Batch 35, Loss: 2.2994
# Epoch 1, Batch 40, Loss: 2.7018
# Epoch 1, Batch 45, Loss: 2.3017
# Epoch 1, Batch 50, Loss: 2.5111
# Epoch 1, Batch 55, Loss: 2.3768
# Epoch 1, Batch 60, Loss: 2.2409
# Epoch 1, Batch 65, Loss: 2.4751
# Epoch 1, Batch 70, Loss: 2.2011
# Epoch 1, Batch 75, Loss: 2.5756
# Epoch 1, Batch 80, Loss: 2.4614
# Epoch 1, Batch 85, Loss: 2.3522
# Epoch 1, Batch 90, Loss: 2.3687
# Epoch 1, Batch 95, Loss: 2.6156
# Epoch 1, Batch 100, Loss: 2.4673
# Epoch 1, Batch 105, Loss: 2.4395
# Epoch 1, Batch 110, Loss: 2.3723
# Epoch 1, Batch 115, Loss: 2.3154
# Epoch 1, Batch 120, Loss: 2.4600
# Epoch 1, Batch 125, Loss: 2.3960
# Epoch 1, Batch 130, Loss: 2.2859
# Epoch 1, Batch 135, Loss: 2.1851
# Epoch 1, Batch 140, Loss: 2.4899
# Epoch 1, Batch 145, Loss: 2.6066
# Epoch 1, Batch 150, Loss: 2.5059
# Epoch 1, Batch 155, Loss: 2.3923
# Epoch 17, Batch 60, Loss: 2.2911
# Epoch 17, Batch 65, Loss: 2.3476
# Epoch 17, Batch 70, Loss: 2.3013
# Epoch 17, Batch 75, Loss: 2.2847
# Epoch 17, Batch 80, Loss: 2.2982
# Epoch 17, Batch 85, Loss: 2.3306
# Epoch 17, Batch 90, Loss: 2.3017
# Epoch 17, Batch 95, Loss: 2.4391
# Epoch 17, Batch 100, Loss: 2.3201
# Epoch 17, Batch 105, Loss: 2.3316
# Epoch 17, Batch 110, Loss: 2.3046
# Epoch 17, Batch 115, Loss: 2.2920
# Epoch 17, Batch 120, Loss: 2.3156
# Epoch 17, Batch 125, Loss: 2.3173
# Epoch 17, Batch 130, Loss: 2.3529
# Epoch 17, Batch 135, Loss: 2.3046
# Epoch 17, Batch 140, Loss: 2.3881
# Epoch 17, Batch 145, Loss: 2.3428
# Epoch 17, Batch 150, Loss: 2.4383
# Epoch 17, Batch 155, Loss: 2.4108
# ✅ Epoch 17/20, Train Loss: 2.3444, Val Loss: 2.3632
# Epoch 18, Batch 0, Loss: 2.3974
# Epoch 18, Batch 5, Loss: 2.3018
# Epoch 18, Batch 10, Loss: 2.2788
# Epoch 18, Batch 15, Loss: 2.3553
# Epoch 18, Batch 20, Loss: 2.2992
# Epoch 18, Batch 25, Loss: 2.4071
# Epoch 18, Batch 30, Loss: 2.3919
# Epoch 18, Batch 35, Loss: 2.3534
# Epoch 18, Batch 40, Loss: 2.4186
# Epoch 18, Batch 45, Loss: 2.3082
# Epoch 18, Batch 50, Loss: 2.2718
# Epoch 18, Batch 55, Loss: 2.3243
# Epoch 18, Batch 60, Loss: 2.2388
# Epoch 18, Batch 65, Loss: 2.3280
# Epoch 18, Batch 70, Loss: 2.2690
# Epoch 18, Batch 75, Loss: 2.2693
# Epoch 18, Batch 80, Loss: 2.3085
# Epoch 18, Batch 85, Loss: 2.2474
# Epoch 18, Batch 90, Loss: 2.4406
# Epoch 18, Batch 95, Loss: 2.2995
# Epoch 18, Batch 100, Loss: 2.2944
# Epoch 18, Batch 105, Loss: 2.4279
# Epoch 18, Batch 110, Loss: 2.4262
# Epoch 18, Batch 115, Loss: 2.3357
# Epoch 18, Batch 120, Loss: 2.3619
# Epoch 18, Batch 125, Loss: 2.3081
# Epoch 18, Batch 130, Loss: 2.3864
# Epoch 18, Batch 135, Loss: 2.3288
# Epoch 18, Batch 140, Loss: 2.4373
# Epoch 18, Batch 145, Loss: 2.3084
# Epoch 18, Batch 150, Loss: 2.4076
# Epoch 18, Batch 155, Loss: 2.2813
# ✅ Epoch 18/20, Train Loss: 2.3468, Val Loss: 2.3629
# Epoch 19, Batch 0, Loss: 2.3768
# Epoch 19, Batch 5, Loss: 2.3258
# Epoch 19, Batch 10, Loss: 2.3792
# Epoch 19, Batch 15, Loss: 2.3121
# Epoch 19, Batch 20, Loss: 2.3571
# Epoch 19, Batch 25, Loss: 2.3730
# Epoch 19, Batch 30, Loss: 2.3842
# Epoch 19, Batch 35, Loss: 2.2690
# Epoch 19, Batch 40, Loss: 2.3342
# Epoch 19, Batch 45, Loss: 2.2384
# Epoch 19, Batch 50, Loss: 2.3630
# Epoch 19, Batch 55, Loss: 2.3069
# Epoch 19, Batch 60, Loss: 2.4155
# Epoch 19, Batch 65, Loss: 2.2966
# Epoch 19, Batch 70, Loss: 2.3528
# Epoch 19, Batch 75, Loss: 2.2813
# Epoch 19, Batch 80, Loss: 2.3299
# Epoch 19, Batch 85, Loss: 2.2232
# Epoch 19, Batch 90, Loss: 2.2761
# Epoch 19, Batch 95, Loss: 2.2895
# Epoch 19, Batch 100, Loss: 2.2976
# Epoch 19, Batch 105, Loss: 2.4268
# Epoch 19, Batch 110, Loss: 2.2902
# Epoch 19, Batch 115, Loss: 2.3743
# Epoch 19, Batch 120, Loss: 2.3442
# Epoch 19, Batch 125, Loss: 2.2918
# Epoch 19, Batch 130, Loss: 2.3747
# Epoch 19, Batch 135, Loss: 2.3765
# Epoch 19, Batch 140, Loss: 2.3152
# Epoch 19, Batch 145, Loss: 2.3305
# Epoch 19, Batch 150, Loss: 2.2958
# Epoch 19, Batch 155, Loss: 2.2729
# ✅ Epoch 19/20, Train Loss: 2.3440, Val Loss: 2.3637
# Epoch 20, Batch 0, Loss: 2.3130
# Epoch 20, Batch 5, Loss: 2.3856
# Epoch 20, Batch 10, Loss: 2.2717
# Epoch 20, Batch 15, Loss: 2.3653
# Epoch 20, Batch 20, Loss: 2.3247
# Epoch 20, Batch 25, Loss: 2.2856
# Epoch 20, Batch 30, Loss: 2.3820
# Epoch 20, Batch 35, Loss: 2.3808
# Epoch 20, Batch 40, Loss: 2.2494
# Epoch 20, Batch 45, Loss: 2.3867
# Epoch 20, Batch 50, Loss: 2.2743
# Epoch 20, Batch 55, Loss: 2.3105
# Epoch 20, Batch 60, Loss: 2.3495
# Epoch 20, Batch 65, Loss: 2.2530
# Epoch 20, Batch 70, Loss: 2.3821
# Epoch 20, Batch 75, Loss: 2.4489
# Epoch 20, Batch 80, Loss: 2.3879
# Epoch 20, Batch 85, Loss: 2.3962
# Epoch 20, Batch 90, Loss: 2.3265
# Epoch 20, Batch 95, Loss: 2.3326
# Epoch 20, Batch 100, Loss: 2.4295
# Epoch 20, Batch 105, Loss: 2.4118
# Epoch 20, Batch 110, Loss: 2.3629
# Epoch 20, Batch 115, Loss: 2.3478
# Epoch 20, Batch 120, Loss: 2.3009
# Epoch 20, Batch 125, Loss: 2.3808
# Epoch 20, Batch 130, Loss: 2.3450
# Epoch 20, Batch 135, Loss: 2.3580
# Epoch 20, Batch 140, Loss: 2.3858
# Epoch 20, Batch 145, Loss: 2.2722
# Epoch 20, Batch 150, Loss: 2.3501
# Epoch 20, Batch 155, Loss: 2.3919
# ✅ Epoch 20/20, Train Loss: 2.3437, Val Loss: 2.3630
# 💾 Model saved to palm_transformer_epoch_20.pth
# 💾 Model saved to palm_transformer_final.pth
# 🏁 Training completed! Final model saved as 'palm_transformer_final.pth'
#
# 📊 Training Summary:
#    Final Train Loss: 2.3437
#    Final Val Loss: 2.3630
#    Best Val Loss: 2.3575

# %%
criterion_score = nn.MSELoss() 
# For text, we'd use CrossEntropy if we had tokens, or MSE if embedding regression
# Here we simulate embedding regression
criterion_text = nn.MSELoss() 

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
